# %%
import pandas as pd
import numpy as np 
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import os
# Out:
# 2024-11-11 08:37:00.485930: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load data set 
all_merged_data = pd.read_csv("all_merged_data.csv")

# %%
sample_size_test = int(all_merged_data.shape[1] * 0.1)  # Calculate 10% of the columns

# Randomly select 10% of the columns
sampled_columns_test = all_merged_data.sample(n=sample_size_test, axis=1, random_state=42)  # Use random_state for reproducibility

# Separate the sampled columns as test columns and the rest as train columns
train = all_merged_data.drop(columns=sampled_columns_test.columns)  # Remaining 90% of columns
test = sampled_columns_test  # 10% of randomly selected columns
test['date'] = all_merged_data['date']  # Add 'date' back to test
train['date'] = all_merged_data['date']  # Add 'date' back to train


sample_size_dev = int(train.shape[1] * 0.1)  # Calculate 10% of the columns
# Randomly select 10% of the columns
sampled_columns_dev = train.sample(n=sample_size_dev, axis=1, random_state=42)  # Use random_state for reproducibility

# Separate the sampled columns as dev columns and the rest as true train columns
train = train.drop(columns=sampled_columns_dev.columns)  # Remaining 90% of columns
dev = sampled_columns_dev  # 10% of randomly selected columns

# %%
# Function to create sequences for one keyword trend
def create_sequences_for_keyword(data_column, time_step):
    X, y = [], []
    for i in range(len(data_column) - time_step):
        X.append(data_column[i:i + time_step])  # Sequence of past 'time_step' values
        y.append(data_column[i + time_step])    # The next value to predict
    return np.array(X), np.array(y)

# %%
# Define the LSTM models to train 

layers = list(range(2, 8))
time_steps = list(range(10, 60, 10))
nodes = [50,75,100]
dropouts = [0.1, 0.2, 0.3]

model_list = [] 

for layer in layers: 
    for time_step in time_steps: 
        for node in nodes:
            for dropout in dropouts: 

                model = Sequential()
                model.add(LSTM(units= node, activation= 'tanh', input_shape= (time_step, 1), return_sequences=True))
                model.add(Dropout(dropout))

                for i in range(layer - 2):  # Starts at 0 and runs for (layer - 2) times
                    model.add(LSTM(units=node, activation='tanh', return_sequences = True))
                    model.add(Dropout(dropout))

                model.add(LSTM(units=node, activation='tanh')) # final hidden layer, not returning sequences 
                model.add(Dropout(dropout))
        
                model.add(Dense(1))  # Output layer to predict the next value for the trend

                model.compile(optimizer='adam', loss='mean_squared_error')
         
                model_list.append(model)
# Out:
# /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
average_mse_per_model = []
layers_per_model = []
nodes_per_model = []
dropout_per_model = []
time_step_per_model = []

for model in model_list: 
    time_step = model.input_shape[1]
    time_step_per_model.append(time_step)
    layers_per_model.append(len(model.layers))
    nodes_per_model.append(model.layers[0].units)
    dropout_per_model.append(model.layers[1].rate)
    
    mse_list = []

    # Iterate over each keyword column, excluding 'date'
    for keyword in train.columns[1:]:  # Skip the 'date' column
        print(f"Training RNN model for keyword: {keyword}")
        
        # Extract the single keyword's trend data
        single_keyword_data = train[keyword].values  # Extract the column data as an array
        
        # Create sequences for the single keyword
        X, y = create_sequences_for_keyword(single_keyword_data, time_step)
        
        # Reshape X to match RNN input format (samples, timesteps, features)
        X = X.reshape((X.shape[0], X.shape[1], 1))  # 1 feature per keyword
        
        # Continue training the model on this keyword's data 
        history = model.fit(X, y, epochs=1, batch_size=16, verbose=1)
    
    # once all data has been seen in training evaluate MSE 
    
    for keyword in dev.columns[1:]: #skip the 'date' column
        # Extract the single keyword's trend data
        single_keyword_data = dev[keyword].values  # Extract the column data as an array
    
        # Create sequences for the single keyword
        X_dev, y_dev = create_sequences_for_keyword(single_keyword_data, time_step)

        # Predict on the validation set
        y_pred = model.predict(X_dev)
    
        # Compute MSE for this keyword
        mse = mean_squared_error(y_dev, y_pred)
        mse_list.append(mse)

    
    average_mse = sum(mse_list) / len(mse_list)
    average_mse_per_model.append(average_mse)



    # create and save a dataframe with the latest results 
    results = pd.DataFrame(
        {'Average MSE': average_mse_per_model,
         'Number of Layers': layers_per_model,
         'Number of Nodes': nodes_per_model,
         'Dropout Rate': dropout_per_model, 
         'Time Step': time_step_per_model
        })

    results.to_csv('HyperParameterTuningResults.csv', index=False)
# Out:
# Training RNN model for keyword: Dumbbells_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 1.0129
# Training RNN model for keyword: Yoga mats_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0557
# Training RNN model for keyword: Resistance bands_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0444
# Training RNN model for keyword: Kettlebells
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019
# Training RNN model for keyword: Treadmills_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0136
# Training RNN model for keyword: Jump ropes_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0135
# Training RNN model for keyword: Protein powder_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2903
# Training RNN model for keyword: Exercise balls
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0066
# Training RNN model for keyword: Weight plates
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036
# Training RNN model for keyword: Rowing machines_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2907e-04
# Training RNN model for keyword: Workout bench
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014
# Training RNN model for keyword: Pull-up bars_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6579e-04
# Training RNN model for keyword: Foam rollers_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0060
# Training RNN model for keyword: Athletic shoes_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018
# Training RNN model for keyword: Yoga blocks
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0586e-04
# Training RNN model for keyword: Fitness trackers_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0549
# Training RNN model for keyword: Gym gloves_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068
# Training RNN model for keyword: Water bottles_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0267
# Training RNN model for keyword: Exercise bikes_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0010
# Training RNN model for keyword: Ankle weights_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3105e-04
# Training RNN model for keyword: Cross trainers
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0097
# Training RNN model for keyword: Pilates ring
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0061
# Training RNN model for keyword: Fitness DVD
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028
# Training RNN model for keyword: Sports bags
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0124
# Training RNN model for keyword: Weighted vests
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0025
# Training RNN model for keyword: Squat racks
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0216
# Training RNN model for keyword: Yoga straps
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035
# Training RNN model for keyword: Punching bags
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9039e-04
# Training RNN model for keyword: Heart rate monitors
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052
# Training RNN model for keyword: Fitness gear
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017
# Training RNN model for keyword: Toning bands
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1998e-04
# Training RNN model for keyword: Stretch bands
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069
# Training RNN model for keyword: Aerobics step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0110
# Training RNN model for keyword: Ab rollers
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032
# Training RNN model for keyword: Bumper plates
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018
# Training RNN model for keyword: Skipping rope
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036
# Training RNN model for keyword: Workout charts
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012
# Training RNN model for keyword: Sandbags
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0439
# Training RNN model for keyword: Kettle balls
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0013
# Training RNN model for keyword: Dumbbell sets
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4277e-04
# Training RNN model for keyword: Stability balls
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8869e-04
# Training RNN model for keyword: Workout tops
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2025e-04
# Training RNN model for keyword: Glute bands
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032
# Training RNN model for keyword: Parallette bars
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010
# Training RNN model for keyword: Adjustable dumbbells
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0074
# Training RNN model for keyword: Wrist wraps
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6712e-04
# Training RNN model for keyword: Stretch mats
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2007e-04
# Training RNN model for keyword: Home gym sets
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022
# Training RNN model for keyword: Exercise gloves
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030
# Training RNN model for keyword: High protein snacks
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5376e-04
# Training RNN model for keyword: Rower machines
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028
# Training RNN model for keyword: Exercise slides
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049
# Training RNN model for keyword: Ab straps
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021
# Training RNN model for keyword: Multi-gym
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012
# Training RNN model for keyword: Plyo boxes
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021
# Training RNN model for keyword: Slam balls
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033
# Training RNN model for keyword: Dumbbell racks
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.2950e-04
# Training RNN model for keyword: Gym chalk
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0046
# Training RNN model for keyword: Jumping mat
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0025
# Training RNN model for keyword: Arm blasters
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1938e-04
# Training RNN model for keyword: Running shoes_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1874
# Training RNN model for keyword: Battle ropes
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2743e-04
# Training RNN model for keyword: T-shirts
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0689
# Training RNN model for keyword: Jeans
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2337.8379
# Training RNN model for keyword: Dresses
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1509.5293
# Training RNN model for keyword: Jackets
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 39.6652
# Training RNN model for keyword: Shoes
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30533.6543
# Training RNN model for keyword: Hats
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 159.1370
# Training RNN model for keyword: Gloves
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.0588
# Training RNN model for keyword: Sweaters
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.9892
# Training RNN model for keyword: Shirts
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 871.7441
# Training RNN model for keyword: Socks
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 87.3316
# Training RNN model for keyword: Coats
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9038
# Training RNN model for keyword: Blazers
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 35.4849
# Training RNN model for keyword: Swimwear
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0340
# Training RNN model for keyword: Sportswear
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6236
# Training RNN model for keyword: Belts
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8719
# Training RNN model for keyword: Sunglasses_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 107.2430
# Training RNN model for keyword: Skirts
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2144
# Training RNN model for keyword: Handbags
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3818
# Training RNN model for keyword: Jewelry
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 688.8862
# Training RNN model for keyword: Necklaces_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1391
# Training RNN model for keyword: Bracelets_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3693
# Training RNN model for keyword: Earrings_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 39.7276
# Training RNN model for keyword: Watches
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.7372
# Training RNN model for keyword: Boots
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4726.5000
# Training RNN model for keyword: High heels
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3466
# Training RNN model for keyword: Sandals
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 130.1550
# Training RNN model for keyword: Vests
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2072
# Training RNN model for keyword: Leggings
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.3296
# Training RNN model for keyword: Activewear
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1071
# Training RNN model for keyword: Accessories
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.7816
# Training RNN model for keyword: Lingerie
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4512
# Training RNN model for keyword: Tights
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2647
# Training RNN model for keyword: Yoga pants
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1312
# Training RNN model for keyword: Beachwear
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0866
# Training RNN model for keyword: Formal wear
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0143
# Training RNN model for keyword: Fashion tops
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0853
# Training RNN model for keyword: Designer brands
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0523
# Training RNN model for keyword: Winter wear
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0325
# Training RNN model for keyword: Summer wear
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0253
# Training RNN model for keyword: Fashion jackets
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0377
# Training RNN model for keyword: Fashion belts
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0151
# Training RNN model for keyword: Graphic tees
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0433
# Training RNN model for keyword: Denim jackets
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0136
# Training RNN model for keyword: Polo shirts
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0587
# Training RNN model for keyword: Wide-leg pants
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0298
# Training RNN model for keyword: Blouses
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0140
# Training RNN model for keyword: Leather jackets
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0178
# Training RNN model for keyword: Cargo pants
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2679
# Training RNN model for keyword: Ankle boots
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1563
# Training RNN model for keyword: Baseball caps_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0178
# Training RNN model for keyword: Straw hats
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0162
# Training RNN model for keyword: Wool sweaters
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0116
# Training RNN model for keyword: Down jackets_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0111
# Training RNN model for keyword: Overalls
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2280
# Training RNN model for keyword: Tube tops
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0630
# Training RNN model for keyword: Windbreakers
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0506
# Training RNN model for keyword: Cardigans
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0151
# Training RNN model for keyword: Rompers
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0217
# Training RNN model for keyword: Dress shoes
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2911
# Training RNN model for keyword: Slip-ons
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0254
# Training RNN model for keyword: Flats
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4830
# Training RNN model for keyword: Ballet flats
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0672
# Training RNN model for keyword: Fashion jewelry
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0369
# Training RNN model for keyword: Hair accessories
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0233
# Training RNN model for keyword: Zipper jackets
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0215
# Training RNN model for keyword: Button-down shirts
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0154
# Training RNN model for keyword: Tank tops
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0723
# Training RNN model for keyword: Mini skirts
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0100
# Training RNN model for keyword: Trench coats
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0094
# Training RNN model for keyword: Hooded sweatshirts
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0125
# Training RNN model for keyword: Bucket hats
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0122
# Training RNN model for keyword: Blazer jackets
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0168
# Training RNN model for keyword: Snow boots
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5693
# Training RNN model for keyword: Chokers_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0227
# Training RNN model for keyword: Designer sunglasses
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084
# Training RNN model for keyword: Travel bags
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0098
# Training RNN model for keyword: Beanies
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0462
# Training RNN model for keyword: Turtlenecks
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0097
# Training RNN model for keyword: Maxi dresses
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0223
# Training RNN model for keyword: Leather bags
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0092
# Training RNN model for keyword: Puffer jackets
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0158
# Training RNN model for keyword: Halter tops
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0722
# Training RNN model for keyword: Soccer balls
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0206
# Training RNN model for keyword: Running shoes_y
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9705
# Training RNN model for keyword: Treadmills_y
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0435
# Training RNN model for keyword: Dumbbells_y
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4108
# Training RNN model for keyword: Baseball bats
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0236
# Training RNN model for keyword: Hiking boots_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0228
# Training RNN model for keyword: Camping tents_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0140
# Training RNN model for keyword: Football helmets
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0151
# Training RNN model for keyword: Bicycles
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0605
# Training RNN model for keyword: Skateboards
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0276
# Training RNN model for keyword: Ski equipment
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0135
# Training RNN model for keyword: Snowboards
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0456
# Training RNN model for keyword: Golf clubs
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3142
# Training RNN model for keyword: Boxing gloves
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0934
# Training RNN model for keyword: Fishing rods
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0270
# Training RNN model for keyword: Kayaks
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1999
# Training RNN model for keyword: Canoes
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0172
# Training RNN model for keyword: Paddles
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0165
# Training RNN model for keyword: Climbing gear_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0107
# Training RNN model for keyword: Gym bags
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0095
# Training RNN model for keyword: Rowing machines_y
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0110
# Training RNN model for keyword: Weight benches
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0247
# Training RNN model for keyword: Resistance bands_y
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0382
# Training RNN model for keyword: Pull-up bars
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0093
# Training RNN model for keyword: Ellipticals_y
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0103
# Training RNN model for keyword: Protein powder_y
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4944
# Training RNN model for keyword: Running gear
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0291
# Training RNN model for keyword: Swim caps
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0205
# Training RNN model for keyword: Soccer cleats
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0951
# Training RNN model for keyword: Basketball jerseys
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0085
# Training RNN model for keyword: Fitness trackers_y
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0688
# Training RNN model for keyword: Hiking backpacks
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0206
# Training RNN model for keyword: Sleeping bags
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0141
# Training RNN model for keyword: Camping stoves
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0120
# Training RNN model for keyword: Headlamps_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0064
# Training RNN model for keyword: Sports sunglasses
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0396
# Training RNN model for keyword: Knee pads
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0105
# Training RNN model for keyword: Ski poles
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0116
# Training RNN model for keyword: Snowshoes
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0183
# Training RNN model for keyword: Life jackets
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0235
# Training RNN model for keyword: Sports uniforms
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0149
# Training RNN model for keyword: Baseball gloves
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0126
# Training RNN model for keyword: Frisbees
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0206
# Training RNN model for keyword: Squash rackets
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0123
# Training RNN model for keyword: Sports towels
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0164
# Training RNN model for keyword: Ankle weights_y
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068
# Training RNN model for keyword: Workout clothes
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066
# Training RNN model for keyword: Fitness mats
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0108
# Training RNN model for keyword: Trekking poles_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0071
# Training RNN model for keyword: Trail running shoes
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0053
# Training RNN model for keyword: Compression socks
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0291
# Training RNN model for keyword: Skipping ropes
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0173
# Training RNN model for keyword: Weightlifting belts
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0129
# Training RNN model for keyword: Boxing bags
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0123
# Training RNN model for keyword: Paintball guns
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068
# Training RNN model for keyword: Baseball caps_y
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0047
# Training RNN model for keyword: Wrist supports
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0082
# Training RNN model for keyword: Fingerless gloves
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0081
# Training RNN model for keyword: Water bladders
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0117
# Training RNN model for keyword: Athletic tape
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0073
# Training RNN model for keyword: Biking helmets
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0109
# Training RNN model for keyword: Ski goggles
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0271
# Training RNN model for keyword: Paddleboards
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063
# Training RNN model for keyword: Dartboards
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0102
# Training RNN model for keyword: Hand wraps
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0317
# Training RNN model for keyword: Mountain bikes
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0467
# Training RNN model for keyword: Gym gloves_y
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0102
# Training RNN model for keyword: Aerobics steps
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0108
# Training RNN model for keyword: Shin guards
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0105
# Training RNN model for keyword: Hip bags
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0085
# Training RNN model for keyword: Cycling jerseys
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0167
# Training RNN model for keyword: Longboards
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0110
# Training RNN model for keyword: Balance boards
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0093
# Training RNN model for keyword: Snow tubes
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069
# Training RNN model for keyword: Arm warmers
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0213
# Training RNN model for keyword: Hammocks_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0111
# Training RNN model for keyword: Athletic shoes_y
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0050
# Training RNN model for keyword: Tennis grips
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0075
# Training RNN model for keyword: Hunting boots
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0133
# Training RNN model for keyword: Outdoor grills
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0062
# Training RNN model for keyword: Baseball hats
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0067
# Training RNN model for keyword: Wrestling shoes
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0159
# Training RNN model for keyword: Sports drinks
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0057
# Training RNN model for keyword: Balloons
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4631
# Training RNN model for keyword: Streamers
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0620
# Training RNN model for keyword: Party hats
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072
# Training RNN model for keyword: Birthday banners
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0080
# Training RNN model for keyword: Confetti
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0188
# Training RNN model for keyword: Table covers_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0097
# Training RNN model for keyword: Party favors
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0121
# Training RNN model for keyword: Cake toppers_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0073
# Training RNN model for keyword: Paper plates
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0073
# Training RNN model for keyword: Party bags
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0058
# Training RNN model for keyword: Plastic cups
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0050
# Training RNN model for keyword: Invitations
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2675
# Training RNN model for keyword: Gift bags
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0448
# Training RNN model for keyword: Pi\'f1atas
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062
# Training RNN model for keyword: Thank you cards
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0076
# Training RNN model for keyword: Party signs
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0095
# Training RNN model for keyword: Disposable utensils
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0075
# Training RNN model for keyword: Straws
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0225
# Training RNN model for keyword: Cupcake toppers
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0104
# Training RNN model for keyword: Party games
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0448
# Training RNN model for keyword: Balloon weights
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0192
# Training RNN model for keyword: Place cards
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0088
# Training RNN model for keyword: Hanging decorations
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0045
# Training RNN model for keyword: Themed plates
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0067
# Training RNN model for keyword: Ribbons
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0077
# Training RNN model for keyword: Wrapping paper
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6786
# Training RNN model for keyword: Banners
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0820
# Training RNN model for keyword: Sparklers
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0682
# Training RNN model for keyword: Party blowers
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0167
# Training RNN model for keyword: Party trays
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0074
# Training RNN model for keyword: LED lights
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4550
# Training RNN model for keyword: Birthday sashes
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0364
# Training RNN model for keyword: Cocktail napkins
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0181
# Training RNN model for keyword: Gift wrap
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1047
# Training RNN model for keyword: Honeycomb decorations
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0070
# Training RNN model for keyword: Plastic tablecloths
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0083
# Training RNN model for keyword: Party crowns
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0112
# Training RNN model for keyword: Noise makers
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0086
# Training RNN model for keyword: Custom balloons
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0101
# Training RNN model for keyword: Birthday invites
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0282
# Training RNN model for keyword: Favor boxes
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0171
# Training RNN model for keyword: Table runners_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044
# Training RNN model for keyword: Ribbon bows
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0085
# Training RNN model for keyword: Confetti poppers
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0121
# Training RNN model for keyword: Mini sparklers
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081
# Training RNN model for keyword: Birthday decor
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0066
# Training RNN model for keyword: Printed tablecloths
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0066
# Training RNN model for keyword: Birthday candles
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048
# Training RNN model for keyword: Table decorations
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0055
# Training RNN model for keyword: Themed napkins
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0076
# Training RNN model for keyword: Hanging lanterns
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0231
# Training RNN model for keyword: Costume accessories
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0183
# Training RNN model for keyword: Candy bags
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0062
# Training RNN model for keyword: Birthday signs
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0114
# Training RNN model for keyword: Inflatable numbers
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072
# Training RNN model for keyword: Party balloons
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0065
# Training RNN model for keyword: Cake toppers_y
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0055
# Training RNN model for keyword: Cake servers
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0058
# Training RNN model for keyword: Cocktail glasses
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048
# Training RNN model for keyword: Candy bar bags
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0052
# Training RNN model for keyword: Fun cups
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0059
# Training RNN model for keyword: LED candles
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060
# Training RNN model for keyword: Shaped balloons
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0085
# Training RNN model for keyword: Streamer kits
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0042
# Training RNN model for keyword: Birthday numbers
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042
# Training RNN model for keyword: Birthday wands
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0044
# Training RNN model for keyword: Glitter confetti
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072
# Training RNN model for keyword: Striped straws
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0058
# Training RNN model for keyword: Paper bunting
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0062
# Training RNN model for keyword: Party glasses
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046
# Training RNN model for keyword: Themed games
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042
# Training RNN model for keyword: Balloon stands
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073
# Training RNN model for keyword: Fun napkins
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047
# Training RNN model for keyword: Balloon strings
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0054
# Training RNN model for keyword: Mini party lights
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0051
# Training RNN model for keyword: Book genres
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0033
# Training RNN model for keyword: Bestsellers
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0171
# Training RNN model for keyword: Classic novels
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0091
# Training RNN model for keyword: Mystery books
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0049
# Training RNN model for keyword: Used books
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0100
# Training RNN model for keyword: Graphic novels_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0123
# Training RNN model for keyword: Young adult
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0183
# Training RNN model for keyword: Historical fiction
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0161
# Training RNN model for keyword: Romance novels_x
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043
# Training RNN model for keyword: Book club
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1594
# Training RNN model for keyword: Sci-fi novels
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0196
# Training RNN model for keyword: Educational books
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0153
# Training RNN model for keyword: Biographies
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0124
# Training RNN model for keyword: Self-help books
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0061
# Training RNN model for keyword: Travel guides
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0054
# Training RNN model for keyword: Bookmarks
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0393
# Training RNN model for keyword: Poetry
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4829
# Training RNN model for keyword: Audiobooks
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0927
# Training RNN model for keyword: Local authors
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0071
# Training RNN model for keyword: Book events
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0054
# Training RNN model for keyword: Reading glasses
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0136
# Training RNN model for keyword: Book recommendations
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0202
# Training RNN model for keyword: Memoirs
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0091
# Training RNN model for keyword: Stationery
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0064
# Training RNN model for keyword: Journals
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0127
# Training RNN model for keyword: Writing supplies
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0209
# Training RNN model for keyword: Book tote bags
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0106
# Training RNN model for keyword: Literary gifts
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0051
# Training RNN model for keyword: Gift cards
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 29.8187
# Training RNN model for keyword: Book trivia
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0075
# Training RNN model for keyword: Book-related gifts
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0072
# Training RNN model for keyword: Banned books
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0707
# Training RNN model for keyword: Comics
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9589
# Training RNN model for keyword: Rare books
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0447
# Training RNN model for keyword: Antique books
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0115
# Training RNN model for keyword: Non-fiction
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0286
# Training RNN model for keyword: Book series
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4075
# Training RNN model for keyword: DIY books
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0832
# Training RNN model for keyword: Language books
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062
# Training RNN model for keyword: Classic literature
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0731
# Training RNN model for keyword: Book sleeves
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0591
# Training RNN model for keyword: Teacher resources
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0088
# Training RNN model for keyword: Child development books
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0081
# Training RNN model for keyword: Collector\'92s edition
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0059
# Training RNN model for keyword: Pocket books
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0318
# Training RNN model for keyword: Book lights
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0346
# Training RNN model for keyword: Author events
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070
# Training RNN model for keyword: Local history
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051
# Training RNN model for keyword: Graphic novels_y
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0038
# Training RNN model for keyword: Reading nooks
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0082
# Training RNN model for keyword: Holiday books
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061
# Training RNN model for keyword: eBooks
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0269
# Training RNN model for keyword: Book boxes
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0631
# Training RNN model for keyword: Religious texts
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1161
# Training RNN model for keyword: DIY notebooks
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0099
# Training RNN model for keyword: Bookish clothes
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0073
# Training RNN model for keyword: Book end sets
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0053
# Training RNN model for keyword: Comic books
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0168
# Training RNN model for keyword: Writing journals
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0128
# Training RNN model for keyword: Quote mugs
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0113
# Training RNN model for keyword: Bible study
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3166
# Training RNN model for keyword: Online bookshop
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2356
# Training RNN model for keyword: Literary posters
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0222
# Training RNN model for keyword: Book earrings
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0100
# Training RNN model for keyword: Magazine rack
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0257
# Training RNN model for keyword: Pop culture books
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0133
# Training RNN model for keyword: Academic books
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0154
# Training RNN model for keyword: Audio storybooks
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0092
# Training RNN model for keyword: Crime novels
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0086
# Training RNN model for keyword: Bookstore cafe
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0078
# Training RNN model for keyword: Writing pens
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0100
# Training RNN model for keyword: Romance novels_y
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047
# Training RNN model for keyword: Bookish jewelry
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0053
# Training RNN model for keyword: Book clubs
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0065
# Training RNN model for keyword: Coffee beans
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0182
# Training RNN model for keyword: French press
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0139
# Training RNN model for keyword: Coffee mugs
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0232
# Training RNN model for keyword: Coffee grinder
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0153
# Training RNN model for keyword: Cold brew kit
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0123
# Training RNN model for keyword: Tea leaves
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040
# Training RNN model for keyword: Espresso cups
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0043
# Training RNN model for keyword: Pour-over set
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039
# Training RNN model for keyword: Coffee scoops
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0131
# Training RNN model for keyword: To-go cups
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061
# Training RNN model for keyword: Organic coffee
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0052
