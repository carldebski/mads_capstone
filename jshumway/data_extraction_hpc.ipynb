# %%
# This notebook is meant for use in the great lakes computing environment
# in order to maximize the amount of data we can extract for our modeling task

# %%
import pandas as pd   
import numpy as np
import pytrends
from pytrends.request import TrendReq
import gtab
import matplotlib.pyplot as plt
import os

# %%
def get_single_keyword_trend_data_gtab(keyword, region='US', time_period='2020-01-01 2024-10-11'):
    """
    Query Google Trends data using GTAB for a single keyword, region, and time period.
    
    Args:
        keyword (str): The keyword to search.
        region (str): Region code (default is 'US').
        time_period (str): Timeframe for the data (default is '2020-01-01 2024-10-11').
    
    Returns:
        pd.DataFrame: Google Trends data for the keyword with Date and Max Ratio (Interest) columns.
    """
    # Initialize GTAB object
    t = gtab.GTAB()

    try:
        # Ensure keyword is a non-empty string
        if not keyword or not isinstance(keyword, str):
            raise ValueError("Invalid keyword provided.")
        
        print(f"Querying keyword: {keyword} in region: {region} for the period {time_period}")
        
        # Query Google Trends using GTAB
        t.set_options(pytrends_config={"timeframe": time_period, 'geo': region})
        trend_data = t.new_query(keyword)
        
      # Check if data is empty
        if trend_data.empty:
            print(f"No data found for keyword: {keyword}")
            return None
        
        # Rename 'max_ratio' to the keyword
        trend_data = trend_data[['max_ratio']].rename(columns={'max_ratio': keyword})
        
        # Reset the index to move 'date' from the index to a column
        trend_data = trend_data.reset_index()

        return trend_data

    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
def load_keywords_from_file(file_path):
    """
    Load keywords from a text file with comma-separated values in one line.

    Args:
        file_path (str): Path to the file containing keywords.

    Returns:
        list: A list of cleaned keywords.
    """
    with open(file_path, 'r') as file:
        # Read the first line and split by comma
        keywords = file.readline().strip().split(',')
    return [kw.strip() for kw in keywords if kw.strip()]  # Clean whitespace and filter out empty strings

# %%
def process_keywords_for_file(file_path, region, time_period):
    """
    Process Google Trends data for keywords in a single file and save it to a DataFrame.

    Args:
        file_path (str): Path to the file containing keywords.
        region (str): Region code.
        time_period (str): Timeframe for the data.

    Returns:
        pd.DataFrame: Combined trend data for all keywords in the file.
    """
    keywords = load_keywords_from_file(file_path)
    combined_trend_data = pd.DataFrame()

    # Loop through each keyword and get trend data
    for keyword in keywords:
        trend_data = get_single_keyword_trend_data_gtab(keyword, region, time_period)

        if trend_data is not None:
            if combined_trend_data.empty:
                combined_trend_data = trend_data
            else:
                combined_trend_data = pd.merge(combined_trend_data, trend_data, on='date', how='outer')
    
    return combined_trend_data

# %%
if __name__ == "__main__":
    # Directory containing keyword text files
    #folder_path = os.getcwd() + '/text_files'
    folder_path = '/home/jshumway/text_files'
    region = 'US'
    time_period = '2020-01-01 2024-10-11'  

    # Iterate through each text file in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt") or filename.endswith(".rtf"):  # Process only text files
            file_path = os.path.join(folder_path, filename)
            
            # Process the file and get the combined trend data
            combined_trend_data = process_keywords_for_file(file_path, region, time_period)
            
            # Define the output CSV file path
            output_csv = os.path.join('/home/jshumway/csv_files', f"{os.path.splitext(filename)[0]}_trend_data.csv")
            
            # Save combined trend data to CSV
            combined_trend_data.to_csv(output_csv, index=False)
# Out:
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Basketballs in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Basketballs'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Soccer balls in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Soccer balls'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Tennis rackets in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Tennis rackets'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Running shoes in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Running shoes'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Treadmills in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Treadmills'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Dumbbells in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query '
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Skipping ropes in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Skipping ropes'
# An error occurred: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Skipping+ropes%22%2C+%22time%22%3A+%222020-01-01+2024-10-11%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Weightlifting belts in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Weightlifting belts'
# An error occurred: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Weightlifting+belts%22%2C+%22time%22%3A+%222020-01-01+2024-10-11%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Boxing bags in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Boxing bags'
# An error occurred: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Boxing+bags%22%2C+%22time%22%3A+%222020-01-01+2024-10-11%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Paintball guns in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Paintball guns'
# An error occurred: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Paintball+guns%22%2C+%22time%22%3A+%222020-01-01+2024-10-11%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Baseball caps in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Baseball caps'
# An error occurred: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Baseball+caps%22%2C+%22time%22%3A+%222020-01-01+2024-10-11%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Wrist supports in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Wrist supports'
# An error occurred: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Wrist+supports%22%2C+%22time%22%3A+%222020-01-01+2024-10-11%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Fingerless gloves in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Fingerless gloves'
# An error occurred: 'NoneType' object has no attribute 'status_code'
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Water bladders in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Water bladders'
# An error occurred: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Water+bladders%22%2C+%22time%22%3A+%222020-01-01+2024-10-11%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Athletic tape in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Athletic tape'
# An error occurred: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Athletic+tape%22%2C+%22time%22%3A+%222020-01-01+2024-10-11%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Biking helmets in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Biking helmets'
# An error occurred: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Biking+helmets%22%2C+%22time%22%3A+%222020-01-01+2024-10-11%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Ski goggles in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Ski goggles'
# An error occurred: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Ski+goggles%22%2C+%22time%22%3A+%222020-01-01+2024-10-11%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Paddleboards in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Paddleboards'
# An error occurred: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Paddleboards%22%2C+%22time%22%3A+%222020-01-01+2024-10-11%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Dartboards in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Dartboards'
# An error occurred: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Dartboards%22%2C+%22time%22%3A+%222020-01-01+2024-10-11%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Hand wraps in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Hand wraps'
# An error occurred: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Hand+wraps%22%2C+%22time%22%3A+%222020-01-01+2024-10-11%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Paragliding kits in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Paragliding kits'
# An error occurred: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Paragliding+kits%22%2C+%22time%22%3A+%222020-01-01+2024-10-11%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Mountain bikes in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Mountain bikes'
# An error occurred: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Mountain+bikes%22%2C+%22time%22%3A+%222020-01-01+2024-10-11%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Gym gloves in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Gym gloves'
# An error occurred: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Gym+gloves%22%2C+%22time%22%3A+%222020-01-01+2024-10-11%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Tackle boxes in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Tackle boxes'
# An error occurred: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Tackle+boxes%22%2C+%22time%22%3A+%222020-01-01+2024-10-11%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Cross-trainers in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Cross-trainers'
# ...
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Leather car seat cover'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Roof-mounted light in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Roof-mounted light'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Car safety kit in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Car safety kit'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Tire shine in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Tire shine'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Vehicle cover in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Vehicle cover'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Battery charger in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Battery charger'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Car dust cleaner in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Car dust cleaner'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Undercoating in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Undercoating'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Exhaust repair kit in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Exhaust repair kit'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Wheel balancing in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Wheel balancing'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Car repair stand in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Car repair stand'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Floor jacks in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Floor jacks'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Dog food in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Dog food'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Cat food in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Cat food'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Fish tanks in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Fish tanks'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Bird cages in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Bird cages'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Pet toys in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Pet toys'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Dog collars in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Dog collars'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Cat litter in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Cat litter'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Puppy pads in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Puppy pads'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Reptile terrariums in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Reptile terrariums'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Dog leashes in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Dog leashes'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Cat treats in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Cat treats'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Fish food in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Fish food'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Pet grooming in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Pet grooming'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Bird feed in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Bird feed'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Pet vitamins in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Pet vitamins'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Dog harness in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Dog harness'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Pet beds in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Pet beds'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Aquarium decorations in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Aquarium decorations'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Litter boxes in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Litter boxes'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Rabbit hay in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Rabbit hay'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Pet clothes in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Pet clothes'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Puppy training pads in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Puppy training pads'
# New query calibrated!
# Using directory '/Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
#
# Querying keyword: Catnip toys in region: US for the period 2020-01-01 2024-10-11
# Using /Users/Jenny/MADS/Capstone/myenv/lib/python3.12/site-packages/gtab/output/google_anchorbanks/google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv
# New query 'Catnip toys'
